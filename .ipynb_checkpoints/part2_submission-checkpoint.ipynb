# %%
import pandas as pd
import numpy as np
import random
# %matplotlib inline
import matplotlib.pyplot as plt
import surprise
from collections import defaultdict
from surprise import SVD, SVDpp, NMF
from surprise import Dataset
from surprise import Reader
from surprise import evaluate, print_perf
from surprise import KNNBasic
from surprise import AlgoBase, BaselineOnly
from get_top_n import get_top_n
from model.hybrid_model import HybridModel
from model.evaluation import evaluation

# %%
df = pd.read_csv('sample_data.csv',index_col=0)

# %%
# Turn data frame into dictionary
df_records = df[['reviewerID','productID']].to_dict('records')
df_dict = defaultdict(list)
for row in df_records:
    df_dict[row['reviewerID']].append(row['productID'])

# %%
# Select % as holdout data
holdout = []
for reviewer in df_dict:
    hd_product = df_dict[reviewer][:max(1,int(0.25*len(df_dict[reviewer])))]
    for product in hd_product:
        holdout.append((reviewer,product))
df_tupleindex = df.set_index(['reviewerID','productID'])

# %%
# Develop training and test data
testdata = df_tupleindex.loc[holdout].reset_index()
traindata = df_tupleindex[~df_tupleindex.index.isin(holdout)].reset_index()

# %% [markdown]
# ## Hybrid Model

# %%
# Divide training data into dense and sparse data, and handle them separately 
sparse_dt, dense_dt = HybridModel.divide_data(traindata,5)

# %%
sparse_dt.describe()
# Out:
#            rating
# count  1552.00000
# mean      3.87049
# std       1.08473
# min       1.00000
# 25%       3.00000
# 50%       4.00000
# 75%       5.00000
# max       5.00000

# %%
dense_dt.describe()
# Out:
#             rating
# count  3153.000000
# mean      3.901047
# std       1.038156
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000

# %% [markdown]
# For dense data, we use a mixed hybrid model with our own Content-based model,
# along with the Matrix Factorization model, neighborhood based model we built in Part I

# %%
# Content-based model and its set of prediction

# %%
# Part I model: SVD model and its set of prediction
reader = Reader(rating_scale=(1,5))
df_surprise = Dataset.load_from_df(dense_dt[['reviewerID','productID','rating']],reader)

# %%
#Construct missing ratings we need to predict
dense_data_select = dense_dt.pivot_table('rating',index=['reviewerID','productID'],dropna=False)
dense_data_select = dense_data_select.loc[dense_data_select['rating'].isnull()]
dense_data_select.reset_index(inplace=True)
missing_values = dense_data_select[['reviewerID','productID']].values

# %%
#Function to predict missing values based on an algorithm
def mv_prediction(algo,missing_values):
    predictions = [algo.predict(uid, iid)
                       for (uid, iid) in missing_values]
    return predictions

# %%
algo1 = SVD()
evaluate(algo1,df_surprise,measures=['RMSE','MAE'], verbose= 0)
# Out:
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [0.7448540593841253,
#                              0.70959026684826021,
#                              0.70721691208136495,
#                              0.78509054267732614,
#                              0.69412464950708552],
#                             'rmse': [0.96388088018646711,
#                              0.88396764062866751,
#                              0.90205229246524865,
#                              0.98571383411272184,
#                              0.87716995383146779]})

# %%
# Extract product recommendation list for each user
def extract_topk_surpise(prediction):
    topk = get_top_n(prediction)
    topk_norating = defaultdict(list)
    for user, i_r in topk.items():
        for item, rating in i_r:
            topk_norating[user].append(item)
    return topk_norating

# %%
# Get top k recommendation from SVD model
mv_svdprediction = mv_prediction(algo1,missing_values)
svd_topk = extract_topk_surpise(mv_svdprediction)

# %%
# Part I Model: KNN and its set of prediction
algo_name = KNNBasic ##  KNNWithMeans,KNNBaseline
sim_option={'name': 'cosine', ## cosine, msd, pearson, personbaseline
                 'user_based': 'False', ## False for item-based
                 'min_surpport':0 }##  if |Iuv|<min_support then sim(u,v)=0
max_k = 10 ## The (max) number of neighbors to take into account for aggregation
min_k = 7 ##  If there are not enough neighbors, the prediction is set the the global mean of all ratings
knn_default = algo_name(k = max_k, min_k = min_k, sim_options=sim_option)
#Train model
evaluate(knn_default, df_surprise, measures=['RMSE','MAE'], verbose= 1)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0384
# MAE:  0.8041
# ------------
# Fold 2
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9397
# MAE:  0.7563
# ------------
# Fold 3
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9536
# MAE:  0.7537
# ------------
# Fold 4
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0320
# MAE:  0.8190
# ------------
# Fold 5
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9461
# MAE:  0.7570
# ------------
# ------------
# Mean RMSE: 0.9820
# Mean MAE : 0.7780
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [0.8040615116117551,
#                              0.7563107556383426,
#                              0.75368403565055664,
#                              0.8189524408330654,
#                              0.75695571243776361],
#                             'rmse': [1.0384211911554688,
#                              0.93974853169298933,
#                              0.95362582354355641,
#                              1.0319986851986822,
#                              0.94607092539861803]})

# %%
# Get top k recommendation from KNN
mv_knnprediction = mv_prediction(knn_default,missing_values)
knn_topk = extract_topk_surpise(mv_knnprediction)

# %% [markdown]
# For sparse data, we use a mixed hybrid model of our own Association rule and Content-based model.
# We already trained the content-based model above, now we need to train the Association rule model

# %%
# Final set of recommendation as mixed recommendation of Content-based, SVD, KNN for dense matrix,
# and mixed recommendation of Content-based, Association rule for sparse matrix
# The recommendations are presented side-by-side to each user
sparse_prediction = HybridModel.recommendation_mixer(svd_topk,knn_topk,n=7)
dense_prediction = HybridModel.recommendation_mixer(svd_topk,knn_topk,n=7)
hybrid_prediction = HybridModel.combine_prediction(sparse_prediction,dense_prediction)
hybrid_prediction
# Out:
# {'A100WO06OQR8BQ': ['B004U8XT10',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B009WPKGQC',
#   'B009M515HG'],
#  'A10ZBR6O8S8OCY': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00DBSG6V0',
#   'B00BJH5A26',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A11I1I9QLMAM1A': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DBSG6V0',
#   'B00BJH5A26'],
#  'A11LNY2OLQSUSV': ['B003EXVM4S',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B00BJH5A26'],
#  'A11OTLEDSW8ZXD': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B00DBSG6V0',
#   'B00BJH59ZO',
#   'B003EXVM4S',
#   'B009M515DA'],
#  'A13MKSASQ6YWL7': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00BNR7I18'],
#  'A13WOT3RSXKRD5': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B003EXXPWA'],
#  'A15T9G38F589KM': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B00BJH5A26'],
#  'A16ALXKQ02SKYG': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B003EXXPWA'],
#  'A16WPA6JV83YXT': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'A16YU3GRGCD95S': ['B00BJH5A26',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B004U8XT10'],
#  'A16Z2OECAUX8Z4': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00934WBRO',
#   'B00338DPRG'],
#  'A184ZFZZBWEXMS': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BJH59ZO',
#   'B003EXXPWA'],
#  'A194K60CWZ371J': ['B00DS842HS',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B009WPKGQC'],
#  'A19UTUEBWKIZFT': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00338DPRG',
#   'B00DUQDIFA'],
#  'A19WEEGB05YAZ3': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B00DUQDIFA'],
#  'A19XMHRB3G4DIR': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A1A1BM6N28X9J0': ['B00DS842HS',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'A1AEPMPA12GUJ7': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B00BJH5A26'],
#  'A1AG7F4Z1EOO5L': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B004GWRP1A'],
#  'A1DG75OT3Y49EM': ['B009WPKGQC',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S'],
#  'A1DH3QDZX8Z7GO': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B00DUQDIMI',
#   'B003EXVM4S'],
#  'A1E1LEVQ9VQNK': ['B003EXVM4S',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B00DBSG6V0',
#   'B003EXXPWA',
#   'B009M5178S'],
#  'A1E5WXNTI7EO2A': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B004U8XT10',
#   'B009WPKGQC'],
#  'A1EVV74UQYVKRY': ['B00BJH5A26',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00DUQDIFA'],
#  'A1F1A0QQP2XVH5': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A1F7YU6O5RU432': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B004U8XT10'],
#  'A1FPQ54AIB26L0': ['B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DS842HS',
#   'B00DBSG6V0',
#   'B009WPKGQC',
#   'B00DUQDIMI',
#   'B003EXVM4S'],
#  'A1GYEGLX3P2Y7P': ['B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIFA',
#   'B00BNR7I18',
#   'B00BJH5A26'],
#  'A1HLJJ6MKZLR3Z': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00DUQDIFA'],
#  'A1HOLJW15Q5S5V': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00DBSG6V0',
#   'B003EXXPWA',
#   'B00DUQDIMI'],
#  'A1HRYC60VTMYC0': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B00BJH59ZO'],
#  'A1I6U5AQAT3ZG9': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A1ITRGMT80D5TK': ['B00BJH5A26',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00DUQDIKU'],
#  'A1IZJVLNMFACS6': ['B003EXXPWA',
#   'B00BNR7I18',
#   'B009WPKGQC',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'A1JBBR4MNGQ70G': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00DUQDIFA'],
#  'A1L7R2764ED46Y': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'A1LHAXBM5GBJS2': ['B00DS842HS',
#   'B00BJH5A26',
#   'B00DUQDIKU',
#   'B009WPKGQC',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'A1M5ZT35YX6TIN': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B00934WBRO',
#   'B0025UK92C'],
#  'A1MAG8BDOVJHTT': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B00BJH5A26'],
#  'A1MZL91Z44RN06': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B009M5178S',
#   'B0025UK92C'],
#  'A1N5FSCYN4796F': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00DUQDIKU',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DBSFXTQ'],
#  'A1ODOGXEYECQQ8': ['B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B009WPKGQC'],
#  'A1ONZ8JRPLBNUI': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00DUQDIMI'],
#  'A1OPZ3BUTEL47R': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'A1P2XYD265YE21': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM66'],
#  'A1PI8VBCXXSGC7': ['B003EXXPWA',
#   'B00BNR7I18',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S'],
#  'A1QBOC76MIOJYP': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BNR7I18'],
#  'A1QR76SYGTXJN5': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B003EXVM4S',
#   'B00BNR7I18'],
#  'A1R1BFJCMWX0Y3': ['B003EXXPWA',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00BJH59ZO'],
#  'A1SB9BNNGKNX2Z': ['B003EXVM4S',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00DS842HS',
#   'B00DBSG6V0',
#   'B00DBSG77S',
#   'B00BJH5A26'],
#  'A1TR1R2QKWRSRA': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S'],
#  'A1UFLVSJ3IRETQ': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00BNR7I18',
#   'B00BJH59ZO'],
#  'A1UINGIK3UG77D': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00DUQDIMI'],
#  'A1UMSB7LAW0RIR': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B003EXVM4S'],
#  'A1UQBFCERIP7VJ': ['B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00338DPRG',
#   'B00DBSG77S',
#   'B0025UK92C'],
#  'A1V1EP514B5H7Y': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00BJH59ZO'],
#  'A1VABWDOUQLULZ': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B003EXXPWA'],
#  'A1VBDMNT6I8RE5': ['B0025UK92C',
#   'B00DS842HS',
#   'B00338DPRG',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004U8XT10'],
#  'A1VQBEW0G4IH1J': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B00AHRDVFM'],
#  'A1W415JP5WEAJK': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S'],
#  'A1WXJ1I42UOQ2V': ['B00DS842HS',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B00BNR7I18',
#   'B004GWRP1A'],
#  'A1X3ESYZ79H59E': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00338DPRG'],
#  'A1YVDY3TISDRE1': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A1YVO5V1SO18DZ': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00934WBRO',
#   'B00DUQDIMI',
#   'B00934S5JM'],
#  'A1Z7Y2GMAP9SRY': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B003EXVM4S',
#   'B00DUQDIMI'],
#  'A1ZENB34HH2EIM': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXXPWA'],
#  'A1ZGHA3IJV01BK': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B00BJH5A26'],
#  'A1ZPY91VE3IDN1': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B00BJH5A26',
#   'B00338DPRG',
#   'B00BJH59ZO',
#   'B009M515GW'],
#  'A1ZU55TM45Y2R8': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DUQDIFA',
#   'B00DUQDIMI'],
#  'A2068BC3ZXAVJQ': ['B003EXVM4S',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DBSFXTQ',
#   'B00338DPRG'],
#  'A20EEWWSFMZ1PN': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B005CT9OYM',
#   'B0025UK92C',
#   'B00BNR7I18'],
#  'A217CC8F7N5717': ['B003EXVM4S',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B003EXXPWA',
#   'B00BJH5A26'],
#  'A21SL94J53BDS9': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B004GWRP1A'],
#  'A22CW0ZHY3NJH8': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B00DUQDIFA',
#   'B00BJH59ZO'],
#  'A22PUBSSNP54L': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH5A26'],
#  'A22VNXHU6IZ5MT': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B003EXVM4S',
#   'B004U8XT10'],
#  'A231LBC8EGPO5L': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'A235UFZGCFN3J5': ['B004U8XT10',
#   'B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00934S5JM',
#   'B00DUQDIFA'],
#  'A23GS4UGLQBG2V': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00BJH5A26'],
#  'A23KDA686N6T4Y': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00DUQDIMI'],
#  'A23RZIU0N8K2KR': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B00DBSG6V0'],
#  'A244CRJ2QSVLZ4': ['B003EXXPWA',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDEZY',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00934WBRO'],
#  'A24RCBRDXRXR0Y': ['B00DS842HS',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B00DUQDIFA',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DUQDIMI'],
#  'A2503LT8PZIHAD': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B004U8XT10'],
#  'A25C2M3QF9G7OQ': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00DUQDIFA',
#   'B003EXXPWA',
#   'B003EXVM4S'],
#  'A25CZCHLNH3OMO': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B009WPKGQC'],
#  'A25KKXUQQ0OLWB': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'A25KVM6GJBLISZ': ['B003EXXPWA',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DUQDIMI'],
#  'A267FU71Z01CIH': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B00BJH59ZO',
#   'B003EXXPWA'],
#  'A26EQ8U96JA92T': ['B004U8XT10',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B009M515DA'],
#  'A276OI0NHBYORX': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'A277TO3PKKNYDH': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B00934WBRO'],
#  'A27H9DOUGY9FOS': ['B00DS842HS',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BJH59ZO'],
#  'A28IIVKXOE1ATF': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B009M515GW',
#   'B003EXVM4S'],
#  'A29M09QBG9TZLP': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DBSG6V0',
#   'B003EXVM4S'],
#  'A2BLFCOPSMBOZ9': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00DUQDIFA',
#   'B00BJH59ZO',
#   'B008GZ1A7I',
#   'B00BJH5A26'],
#  'A2BPB05QNCE00B': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00DUQDIKU',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00DUQDIFA'],
#  'A2BZ16RKE13PKV': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BNR7I18'],
#  'A2CNGARED6OWWU': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B007N04AF6',
#   'B003EXXPWA'],
#  'A2CZ98V784SRJ0': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B00BJH5A26'],
#  'A2DA2NJZ2RIYAB': ['B004U8XT10',
#   'B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B004GWRP1A'],
#  'A2FFWYG9YYZFA5': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00934WBRO',
#   'B003EXVM4S'],
#  'A2FNA5903D9E6Y': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00934WBRO',
#   'B004GWRP1A',
#   'B0096RP84Q'],
#  'A2G04D4QZAXL15': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BNR7I18'],
#  'A2H2I5FY1PUHP1': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B008GZ1A7I'],
#  'A2I05FGBTCRRB8': ['B00BJH5A26',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00DUQDIFA'],
#  'A2L35P0VQE7LBN': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00DUQDIFA'],
#  'A2L6QS8SVHT9RG': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B003EXXPWA'],
#  'A2LDGL943QZXGK': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A2LRNLAV0ZIL4U': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00934WBRO',
#   'B003EXVM4S'],
#  'A2LW5AL0KQ9P1M': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00BNR7I18',
#   'B004GWRP1A'],
#  'A2LXX47A0KMJVX': ['B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B007N04AF6',
#   'B003EXVM4S',
#   'B00934WBRO'],
#  'A2M6B16568F7KH': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B00BJH5A26'],
#  'A2MNB77YGJ3CN0': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B00BJH5A26'],
#  'A2MUGFV2TDQ47K': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B009WPKGQC'],
#  'A2NUBL2UYWPBWR': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'A2OCDK0BOW6UCY': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00DBSG6V0',
#   'B00DUQDIFA'],
#  'A2OL0JTU0DLH6B': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'A2P739KOM4U5JB': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A2PD27UKAD3Q00': ['B00DS842HS',
#   'B004U8XT10',
#   'B0025UK92C',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIFA'],
#  'A2PSD2R9A1CXG7': ['B00DS842HS',
#   'B00DBSG6V0',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00DUQDIKU',
#   'B009WPKGQC',
#   'B00DUQDIMI'],
#  'A2QDOJFFLFGF18': ['B00DS842HS',
#   'B00DUQDEZY',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXXPWA'],
#  'A2R1HUYHXV7H18': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DBSG77S'],
#  'A2RQOO8VYAEZZG': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DUQDIFA'],
#  'A2RX62V4E2BF5Z': ['B004U8XT10',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00DUQDIKU',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'A2S26YGSVXBCFL': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00AHRDVFM'],
#  'A2SNRRXE9M9ZDY': ['B004U8XT10',
#   'B00DS842HS',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B004GWRP1A',
#   'B00DUQDIFA',
#   'B003EXVM4S'],
#  'A2SZLNSI5KOQJT': ['B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A2TBAUW2W7J538': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BJH5A26'],
#  'A2UEB48LAWFUCW': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B00BNR7I18'],
#  'A2UOHALGF2X77Q': ['B00DS842HS',
#   'B00BJH5A26',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXVM4S'],
#  'A2UT0FWM1DHKFJ': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00DBSG6V0',
#   'B004GWRP1A',
#   'B00BJH5A26'],
#  'A2V4P6IRCK1P70': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00BNR7I18'],
#  'A2V92F5R7MLCVI': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00BNR7I18'],
#  'A2VH0UT5EQFB6P': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B004U8XT10'],
#  'A2W9I628I6SE1U': ['B004U8XT10',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A2WB4OWBUH2VQX': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B00BNR7I18',
#   'B00BJH59ZO',
#   'B003EXVM4S'],
#  'A2WW57XX2UVLM6': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00DBSG6V0',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B00BJH5A26'],
#  'A2WZNM833CJH82': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B00338DPRG'],
#  'A2X2WTEVCZ5L8N': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00DUQDEZY'],
#  'A2XA8CW5DF4MNZ': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXVM4S'],
#  'A2XCCN239AR1XK': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00DBSG77S',
#   'B00BJH59ZO',
#   'B00DUQDIMI'],
#  'A2YKWYC3WQJX5J': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00DBSG6V0',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A2YQ2ZI65F37N8': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B005CT9OYM'],
#  'A2YW1MG1GKU8XD': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00DUQDIFA',
#   'B003EXXPWA'],
#  'A2ZHH7AK83JB5G': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00934WBRO',
#   'B003EXVM4S'],
#  'A2ZY49IDE6TY5I': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B00DUQDIFA',
#   'B009M515DA',
#   'B00BJH5A26'],
#  'A3091RP0SPZLMN': ['B00DS842HS',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B003EXVM66'],
#  'A3094EPI56GKZ6': ['B004GWRP1A',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B00DBSG6V0',
#   'B003EXXPWA'],
#  'A31RULW0KNYJ5H': ['B00DUQDIMI',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO'],
#  'A31XW1RTQ4ZG9W': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B003EXXPWA',
#   'B00BJH59ZO'],
#  'A32EOHLFZYXJEP': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B00BNR7I18'],
#  'A33PVCHCQ2BTN0': ['B003EXXPWA',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B0025UK92C',
#   'B004GWRP1A'],
#  'A33Y8C4818EJL0': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B00BNR7I18'],
#  'A3436BWMMFP4VY': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'A34BZM6S9L7QI4': ['B004U8XT10',
#   'B003EXVM4S',
#   'B009WPKGQC',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B004GWRP1A'],
#  'A34CSXOGVYF94S': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00BNR7I18'],
#  'A353U0L2HAMSHV': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDEZY'],
#  'A35JP8KSV9281K': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'A35LT14WG5BX0T': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B00BJH59ZO'],
#  'A35Q0RBM3YNQNF': ['B00DS842HS',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B009WPKGQC'],
#  'A36MP37DITBU6F': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B009WPKGQC',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A376OJHLE6SU9Q': ['B00DS842HS',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B0025UK92C',
#   'B009M515GW'],
#  'A37MH7ICH80QOX': ['B00DUQDIMI',
#   'B00DBSG6V0',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B004U8XT10'],
#  'A3A7Y3TSPPZU9T': ['B004U8XT10',
#   'B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A3AQO91DYWF8R0': ['B00DS842HS',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BNR7I18'],
#  'A3ATKIU6MZZ4MU': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B003EXVM4S'],
#  'A3AZI828WJN1CD': ['B003EXXPWA',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B009WPKGQC'],
#  'A3BFDEBT5IV4UN': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'A3BKNXX8QFIXIV': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00DUQDIFA',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B00338DPRG'],
#  'A3CG6YLYZJXQG4': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00DBSFXTQ'],
#  'A3CG93783LP0FO': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH5A26'],
#  'A3D9NUCR4RXDPY': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00BJH5A26'],
#  'A3DOPYDOS49I3T': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIFA',
#   'B003EXXPWA'],
#  'A3EK2KTYHJCPB9': ['B00DS842HS',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B00934WBRO',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B004GWRP1A'],
#  'A3EPHBMU07LZ50': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00DBSG6V0',
#   'B00DUQDIMI',
#   'B009WPKGQC',
#   'B00BNR7I18',
#   'B003EXVM4S'],
#  'A3EXIZWHSNVNME': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'A3EXWV8FNSSFL6': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A'],
#  'A3FBM0RMCMAABV': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B00DUQDIFA'],
#  'A3FEGTOLCWXSV4': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00338DPRG',
#   'B00DBSG6V0'],
#  'A3FKGKUCI3DG9U': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B003EXXPWA',
#   'B00DUQDIMI'],
#  'A3HAA7H8PBVM78': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00BNR7I18'],
#  'A3HPCRD9RX351S': ['B004U8XT10',
#   'B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B003EXXPWA'],
#  'A3HQAPXAJV7PRX': ['B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00DBSG6V0',
#   'B00BJH59ZO',
#   'B00BJH5A26'],
#  'A3IUW081KXD3PE': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B004GWRP1A'],
#  'A3J029KBNG5MNP': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00BJH59ZO',
#   'B003EXVM4S'],
#  'A3JPFWKS83R49V': ['B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'A3LGT6UZL99IW1': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B009WPKGQC'],
#  'A3LN4AOPBIUQWR': ['B00DS842HS',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B009M515GW',
#   'B009WPKGQC'],
#  'A3LZA698SQPCXE': ['B004U8XT10',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'A3MDA891A1EPT8': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B003EXVM4S'],
#  'A3MJYQFHRYLUUB': ['B00DS842HS',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B009WPKGQC',
#   'B00BJH59ZO'],
#  'A3MUSWDCTZINQZ': ['B00DS842HS',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B00DUQDIMI',
#   'B00DUQDIFA',
#   'B00BJH59ZO',
#   'B00DBSG6V0'],
#  'A3NHUQ33CFH3VM': ['B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DUQDIFA',
#   'B009M515GW',
#   'B009WPKGQC'],
#  'A3NM1MT3Q2FHXV': ['B00DS842HS',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A3OC93X866Z8TB': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B00BNR7I18'],
#  'A3OXHLG6DIBRW8': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B00DBSG77S'],
#  'A3PJZ8TU8FDQ1K': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B00DBSG6V0',
#   'B004GWRP1A',
#   'B00BJH5A26'],
#  'A3QNQQKJTL76H0': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B00BJH5A26'],
#  'A3QVAKVRAH657N': ['B00DS842HS',
#   'B009WPKGQC',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00BNR7I18',
#   'B00BJH59ZO',
#   'B00DBSFXTQ'],
#  'A3R1WFO4KIUQXZ': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B009M5178S'],
#  'A3R5GTYQ50QVMD': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00338DPRG'],
#  'A3R9H6OKZHHRJD': ['B00DS842HS',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BNR7I18'],
#  'A3RR2P5IS3DGPR': ['B00DUQDIMI',
#   'B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00BJH5A26'],
#  'A3S3R88HA0HZG3': ['B004GWRP1A',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B00BJH5A26'],
#  'A3T4OHEAHOJ700': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00DUQDIFA',
#   'B00BJH5A26',
#   'B0096RP84Q',
#   'B0025UK92C'],
#  'A3TAS1AG6FMBQW': ['B00DS842HS',
#   'B009WPKGQC',
#   'B00DBSG6V0',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B00DUQDIKU'],
#  'A3TJSWA0W9ITYE': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A3TMBYDFP1B9DM': ['B004GWRP1A',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B00DUQDIMI'],
#  'A3U029B8Z5WGI2': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B009WPKGQC'],
#  'A3UKWQS8SRW6IO': ['B004GWRP1A',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00BNR7I18',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B007N04AF6'],
#  'A3V15SFD7918WZ': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B009WPKGQC',
#   'B00DUQDIMI'],
#  'A3VBXQKRM7A4JR': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BJH5A26'],
#  'A3VI2VETB90ZG5': ['B00DS842HS',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00338DPRG',
#   'B00BNR7I18'],
#  'A3VJ27010XUWTF': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B00DUQDIMI'],
#  'A3VLCQX7NG1N0E': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A4D5B7Q8A7PA6': ['B00BJH5A26',
#   'B0096RP84Q',
#   'B00DS842HS',
#   'B003EXVM66',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B00BJH59ZO'],
#  'A4WEZJOIZIV4U': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B003EXVM4S'],
#  'A55PK06Q6AKFY': ['B00DS842HS',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'A5GPH59NDWJRB': ['B00DUQDIMI',
#   'B00BNR7I18',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00DUQDIFA'],
#  'A6VSWJVTWEOII': ['B00DS842HS',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B00BJH59ZO'],
#  'A6X1O3A5C5FX1': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B009M515GW'],
#  'A914TQVHI872U': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BNR7I18'],
#  'A91TB0WX94MHP': ['B004GWRP1A',
#   'B00DS842HS',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B00CSS40LW'],
#  'A9KLAL1CXZ0W5': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00DUQDIMI'],
#  'AAA0TUKS5VBSA': ['B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00DUQDEZY',
#   'B0025UK92C',
#   'B00338DPRG'],
#  'AC6LV5D2RKTIR': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'ACJT8MUC0LRF0': ['B004GWRP1A',
#   'B00DS842HS',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DUQDEZY',
#   'B009WPKGQC',
#   'B00DBSG6V0'],
#  'ACR4HKUT808U1': ['B00DS842HS',
#   'B003EXXPWA',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BJH59ZO',
#   'B00BNR7I18'],
#  'AEC90GPFKLAAW': ['B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00BNR7I18',
#   'B009WPKGQC'],
#  'AEL6CQNQXONBX': ['B004U8XT10',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B005CT9OYM',
#   'B0025UK92C'],
#  'AFFVUZEGP1FDQ': ['B009WPKGQC',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BNR7I18'],
#  'AFICF7DKHTQ87': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00BJH59ZO'],
#  'AGEKVD8JPZQMT': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B0025UK92C',
#   'B004GWRP1A',
#   'B003EXXPWA'],
#  'AGVWTYW0ULXHT': ['B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00DUQDIKU',
#   'B00BJH5A26',
#   'B00BNR7I18'],
#  'AHUT55E980RDR': ['B00DS842HS',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00DUQDIMI'],
#  'AI0PLL5DQAHRG': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIKU',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B004GWRP1A'],
#  'AIEEK7AHXKZCC': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B00BJH5A26',
#   'B00BNR7I18',
#   'B009WPKGQC',
#   'B00DBSG6V0'],
#  'AIFLY2HF8NS8U': ['B00DS842HS',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B00DUQDIFA'],
#  'AK9FTWLCW09RR': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00934WBRO',
#   'B003EXVM4S',
#   'B003EXXPWA'],
#  'ALDAF4VVLFRHP': ['B004U8XT10',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B003EXXPWA'],
#  'ALNFHVS3SC4FV': ['B004U8XT10',
#   'B00DS842HS',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00DUQDIFA',
#   'B00DBSFXTQ'],
#  'ALQ4USPEQ9L5N': ['B004U8XT10',
#   'B00DS842HS',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B003EXVM4S'],
#  'ALYZJ7W14YS26': ['B00DS842HS',
#   'B00BJH5A26',
#   'B00DUQDIMI',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B00338DPRG',
#   'B0025UK92C'],
#  'AM18CU72YEWH5': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B005CT9OYM',
#   'B00BJH5A26',
#   'B009M515DA'],
#  'AN0U0GNJJPEUR': ['B00DS842HS',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B0025UK92C'],
#  'AN9J46667D80O': ['B00DS842HS',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B003EXVM66',
#   'B00DUQDIMI',
#   'B009WPKGQC',
#   'B00BJH59ZO'],
#  'ANTN61S4L7WG9': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B005CT9OYM',
#   'B00DUQDIMI',
#   'B00BJH5A26'],
#  'AO9UNKQG83BUP': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIFA',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH59ZO',
#   'B004GWRP1A'],
#  'AOAOARIH72UWI': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B00DUQDIMI',
#   'B00BJH59ZO',
#   'B00BNR7I18',
#   'B004GWRP1A'],
#  'AOE0XMITAJWDT': ['B00BJH5A26',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00DUQDIKU',
#   'B004GWRP1A',
#   'B009M516HA',
#   'B00DUQDIFA'],
#  'AOEUN9718KVRD': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B0025UK92C',
#   'B00DUQDIFA'],
#  'AOTMP0OKJOUWI': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00DBSG6V0',
#   'B00DBSG77S',
#   'B00BJH5A26'],
#  'APP35M28G2U51': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B003EXVM4S'],
#  'AQ6AGWKWMTY8H': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B00BNR7I18',
#   'B003EXVM66'],
#  'AQM0K7MBBT4AY': ['B00DS842HS',
#   'B00DUQDIMI',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B009WPKGQC',
#   'B004GWRP1A'],
#  'AQY5XBYSENNZQ': ['B00DS842HS',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B003EXXPWA',
#   'B00BNR7I18',
#   'B004GWRP1A',
#   'B004U8XT10'],
#  'ARSQ2F9U315WG': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXVM4S',
#   'B00BJH59ZO',
#   'B005CT9OEW'],
#  'ASF0R1CMSF26F': ['B00DS842HS',
#   'B004GWRP1A',
#   'B004U8XT10',
#   'B00BJH59ZO',
#   'B00DUQDIFA',
#   'B00DUQDIMI',
#   'B00934WBRO'],
#  'AT53ZTTO707MB': ['B00BJH59ZO',
#   'B004U8XT10',
#   'B003EXXPWA',
#   'B00DUQDIMI',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B003EXVM4S'],
#  'ATANE2SC44592': ['B00DS842HS',
#   'B004U8XT10',
#   'B009WPKGQC',
#   'B00DUQDIMI',
#   'B003EXXPWA',
#   'B00DUQDIFA',
#   'B00BJH59ZO'],
#  'ATLO3YXU2BC16': ['B004GWRP1A',
#   'B00BJH5A26',
#   'B004U8XT10',
#   'B00DS842HS',
#   'B00BJH59ZO',
#   'B00BNR7I18',
#   'B003EXXPWA'],
#  'AW6J9IILGOZY3': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B003EXXPWA',
#   'B00DUQDIFA',
#   'B00BJH59ZO'],
#  'AWKZAUC0D8DYL': ['B00DS842HS',
#   'B004U8XT10',
#   'B00DUQDIMI',
#   'B004GWRP1A',
#   'B003EXXPWA',
#   'B003EXVM4S',
#   'B00BJH59ZO'],
#  'AXHETL0M8XZPT': ['B00DS842HS',
#   'B004U8XT10',
#   'B00BJH5A26',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00DUQDIMI'],
#  'AY3D7DG5L5WCK': ['B0025UK92C',
#   'B00DS842HS',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B00DUQDIMI',
#   'B004U8XT10'],
#  'AY6A8KPYCE6B0': ['B00DS842HS',
#   'B004U8XT10',
#   'B003EXVM4S',
#   'B004GWRP1A',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B00DUQDIMI'],
#  'AY8RR5LJIYM8C': ['B00DS842HS',
#   'B00BJH5A26',
#   'B00DUQDIMI',
#   'B003EXVM4S',
#   'B004U8XT10',
#   'B00934WBRO',
#   'B00BJH59ZO'],
#  'AYB4ELCS5AM8P': ['B00DUQDIMI',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B009WPKGQC',
#   'B00BJH5A26',
#   'B00BJH59ZO',
#   'B004U8XT10'],
#  'AYNAH993VDECT': ['B00DS842HS',
#   'B004U8XT10',
#   'B004GWRP1A',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B00DUQDIFA',
#   'B00BJH59ZO']}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Recall at top-k:
# For each user, check if the prediction contains any of products in the holdout set. If yes, we count
# the prediction as a success, and a failure otherwise. Recall at top-k is measured as percentage of
# users with sucessful recommendation out of total number of users. This measurement is based on the
# same idea as in this paper: https://arxiv.org/pdf/1703.02344.pdf

# %%
# Recall at top k
evaluation.recall_at_topk(hybrid_prediction,testdata)
# Out:
# 0.28413284132841327

# %%
# Coverage ratio
# Coverage ratio is measured as number of products recommended over total number of products
evaluation.coverage_ratio(hybrid_prediction,df)
# Out:
# 0.4714285714285714
