# %%
import pandas as pd
import numpy as np
import csv
import pprint
import json


satisfied_value = 1
pp = pprint.PrettyPrinter(width=3000, indent=4)
dict_ = {}

with open('data/meta_Grocery_and_Gourmet_Food.json', 'r') as file:

        data = json.load(file)

    # for item in data:
    #     pp.pprint(item)
# Out:
# ---------------------------------------------
# JSONDecodeErrorTraceback (most recent call last)
# <ipython-input-2-f7f77bbb94f8> in <module>()
#      12 with open('data/meta_Grocery_and_Gourmet_Food.json', 'r') as file:
#      13
# ---> 14         data = json.load(file)
#      15
#      16     # for item in data:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %%
transaction = []
for user in dict_:
    transaction.append(list(dict_[user].keys()))

# %%
transaction
# Out:
# [['B0016B9FSU', 'B00934WBRO', 'B00DUQDIFA'],
#  ['B0016B9FSU', 'B00C7MGHVA'],
#  ['B0016B9FSU', 'B00338DPRG', 'B005V9YXTO', 'B00934WBRO', 'B00AHRDVFM'],
#  ['B0016B9FSU', 'B00DS842HS'],
#  ['B0016B9FSU', 'B0026ZYZ7Q', 'B003EXVM4S', 'B00934WBRO'],
#  ['B0016B9FSU',
#   'B0026ZYZ7Q',
#   'B005CT9OEW',
#   'B008GZ1A7I',
#   'B00934WBRO',
#   'B0096RP84Q',
#   'B009WPKGQC',
#   'B00B9AAI9S',
#   'B00DUQDIFA',
#   'B00DUQDIMI'],
#  ['B0016B9FSU',
#   'B0026ZYZ7Q',
#   'B003EXVM4S',
#   'B003EXXPWA',
#   'B004GWRP1A',
#   'B004TPUT9Y',
#   'B005CT9OEW',
#   'B005HGJ3ZK',
#   'B005V9YXTO',
#   'B008YUL4CQ',
#   'B0091146V8',
#   'B00934WBRO',
#   'B0096RP84Q',
#   'B009WPKGQC',
#   'B00AHRDVFM',
#   'B00APKBFFO',
#   'B00B2JRNBM',
#   'B00BDFNTNQ',
#   'B00C7MGHVA',
#   'B00DBSG6V0',
#   'B00DBSG77S',
#   'B00GLP9JI2'],
#  ['B0016B9FSU',
#   'B0025UCHT0',
#   'B0025UK92C',
#   'B0026ZYZ7Q',
#   'B005CT9OEW',
#   'B007K5KAJY',
#   'B008YUL4CQ',
#   'B00934S312',
#   'B00934S5JM',
# ...

# %%
patterns = pyfpgrowth.find_frequent_patterns(transaction, 10)
# Out:
# ---------------------------------------------
# NameError   Traceback (most recent call last)
# <ipython-input-84-a996b6814c05> in <module>()
# ----> 1 patterns = pyfpgrowth.find_frequent_patterns(transaction, 10)
#
# NameError: name 'pyfpgrowth' is not defined

# %%
patterns
# Out:
# 876

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 0.5)

# %%
rules
# Out:
# ['B003EXVM66',
#  'B005CT9OYM',
#  'B008GZ1A7I',
#  'B008I1XLDQ',
#  'B00APKBFFO',
#  'B00APKBFFY']

# %%
dataframe[dataframe.loc[items[0]]>0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------
# IndexingErrorTraceback (most recent call last)
# <ipython-input-81-b358436f7ae6> in <module>()
# ----> 1 dataframe[dataframe.loc[items[0]]>0]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
# ...

# %%
dict_ = {}
for row in dt.itertuples():
    dict_.setdefault(row.reviewID,[])
    dict_[row.reviewID].append(row.productID)
